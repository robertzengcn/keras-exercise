# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
pd.options.mode.chained_assignment = None

# %%
df=pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
#drop customer ID column as it is not useful
df1=df.drop(['CustomerId','Surname','RowNumber'],axis=1)

# %%
df1.sample(5)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 5828          709     Spain  Female   37       8       0.00              3
# 4135          712    France  Female   29       3   87375.78              2
# 5049          784     Spain    Male   38      10  122267.85              1
# 2854          748    France    Male   33       1  142645.43              1
# 862           725    France    Male   41       7  113980.21              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 5828          1               0         71738.56       0
# 4135          0               0        166194.53       0
# 5049          0               0        145759.93       0
# 2854          0               0         69132.66       0
# 862           1               1        116704.25       0

# %%
for col in df1.columns:
    print(col,':',df1[col].unique())
# Out:
# CreditScore : [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
#  801 611 802 745 483 690 492 709 705 560 752 701 537 487 596 702 486 724
#  548 464 790 534 748 494 590 468 509 818 816 536 753 774 621 569 658 798
#  641 542 692 639 765 570 638 599 632 779 527 564 833 504 842 508 417 598
#  741 607 761 848 546 439 755 760 526 713 700 666 566 495 688 612 477 427
#  839 819 720 459 503 624 529 563 482 796 445 746 786 554 672 787 499 844
#  450 815 838 803 736 633 600 679 517 792 743 488 421 841 708 507 505 456
#  435 561 518 565 728 784 552 609 764 697 723 551 444 719 496 541 830 812
#  677 420 595 617 809 500 826 434 513 478 797 363 399 463 780 452 575 837
#  794 824 428 823 781 849 489 431 457 768 831 359 820 573 576 558 817 449
#  440 415 821 530 350 446 425 740 481 783 358 845 451 458 469 423 404 836
#  473 835 466 491 351 827 843 365 532 414 453 471 401 810 832 470 447 422
#  825 430 436 426 408 847 418 437 410 454 407 455 462 386 405 383 395 467
#  433 442 424 448 441 367 412 382 373 419]
# Geography : ['France' 'Spain' 'Germany']
# Gender : ['Female' 'Male']
# Age : [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]
# Tenure : [ 2  1  8  7  4  6  3 10  5  9  0]
# Balance : [     0.    83807.86 159660.8  ...  57369.61  75075.31 130142.79]
# NumOfProducts : [1 3 2 4]
# HasCrCard : [1 0]
# IsActiveMember : [1 0]
# EstimatedSalary : [101348.88 112542.58 113931.57 ...  42085.58  92888.52  38190.78]
# Exited : [1 0]

# %%
df1.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# Handle Geography, generate new columns

# %%
df2=pd.get_dummies(data=df1,columns=['Geography'])

# %%
df2.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited',
#        'Geography_France', 'Geography_Germany', 'Geography_Spain'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1242          696    Male   30       4  114027.70              1          1
# 4576          697  Female   40       7  130334.35              2          0
# 8097          626  Female   52       0       0.00              2          1
# 3394          466    Male   29       6       0.00              2          1
# 7160          640    Male   23       3   72012.76              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 1242               1        193716.56       0             False
# 4576               1        116951.10       0             False
# 8097               0         32159.46       1              True
# 3394               1          2797.27       0              True
# 7160               0        161333.13       0             False
#
#       Geography_Germany  Geography_Spain
# 1242               True            False
# 4576              False             True
# 8097              False            False
# 3394              False            False
# 7160               True            False

# %% [markdown]
# replace male to 1 , female to 0

# %%
df2['Gender'].replace({'Male':1,'Female':0},inplace=True)
df2['Gender'] = df2['Gender'].astype(int)
# Out:
# C:\Users\zengj\AppData\Local\Temp\ipykernel_25320\2856072829.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Gender'].replace({'Male':1,'Female':0},inplace=True)
# C:\Users\zengj\AppData\Local\Temp\ipykernel_25320\2856072829.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df2['Gender']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %%
for col in df2.columns:
    print(col,':',df2[col].unique())
# Out:
# CreditScore : [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
#  801 611 802 745 483 690 492 709 705 560 752 701 537 487 596 702 486 724
#  548 464 790 534 748 494 590 468 509 818 816 536 753 774 621 569 658 798
#  641 542 692 639 765 570 638 599 632 779 527 564 833 504 842 508 417 598
#  741 607 761 848 546 439 755 760 526 713 700 666 566 495 688 612 477 427
#  839 819 720 459 503 624 529 563 482 796 445 746 786 554 672 787 499 844
#  450 815 838 803 736 633 600 679 517 792 743 488 421 841 708 507 505 456
#  435 561 518 565 728 784 552 609 764 697 723 551 444 719 496 541 830 812
#  677 420 595 617 809 500 826 434 513 478 797 363 399 463 780 452 575 837
#  794 824 428 823 781 849 489 431 457 768 831 359 820 573 576 558 817 449
#  440 415 821 530 350 446 425 740 481 783 358 845 451 458 469 423 404 836
#  473 835 466 491 351 827 843 365 532 414 453 471 401 810 832 470 447 422
#  825 430 436 426 408 847 418 437 410 454 407 455 462 386 405 383 395 467
#  433 442 424 448 441 367 412 382 373 419]
# Gender : [0 1]
# Age : [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]
# Tenure : [ 2  1  8  7  4  6  3 10  5  9  0]
# Balance : [     0.    83807.86 159660.8  ...  57369.61  75075.31 130142.79]
# NumOfProducts : [1 3 2 4]
# HasCrCard : [1 0]
# IsActiveMember : [1 0]
# EstimatedSalary : [101348.88 112542.58 113931.57 ...  42085.58  92888.52  38190.78]
# Exited : [1 0]
# Geography_France : [ True False]
# Geography_Germany : [False  True]
# Geography_Spain : [False  True]

# %%
True_or_False_columns=['Geography_France','Geography_Germany','Geography_Spain']
for col in True_or_False_columns:
    df2[col]=df2[col].astype(int)

# %%
for col in df2.columns:
    print(col,':',df2[col].unique())
# Out:
# CreditScore : [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
#  801 611 802 745 483 690 492 709 705 560 752 701 537 487 596 702 486 724
#  548 464 790 534 748 494 590 468 509 818 816 536 753 774 621 569 658 798
#  641 542 692 639 765 570 638 599 632 779 527 564 833 504 842 508 417 598
#  741 607 761 848 546 439 755 760 526 713 700 666 566 495 688 612 477 427
#  839 819 720 459 503 624 529 563 482 796 445 746 786 554 672 787 499 844
#  450 815 838 803 736 633 600 679 517 792 743 488 421 841 708 507 505 456
#  435 561 518 565 728 784 552 609 764 697 723 551 444 719 496 541 830 812
#  677 420 595 617 809 500 826 434 513 478 797 363 399 463 780 452 575 837
#  794 824 428 823 781 849 489 431 457 768 831 359 820 573 576 558 817 449
#  440 415 821 530 350 446 425 740 481 783 358 845 451 458 469 423 404 836
#  473 835 466 491 351 827 843 365 532 414 453 471 401 810 832 470 447 422
#  825 430 436 426 408 847 418 437 410 454 407 455 462 386 405 383 395 467
#  433 442 424 448 441 367 412 382 373 419]
# Gender : [0 1]
# Age : [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]
# Tenure : [ 2  1  8  7  4  6  3 10  5  9  0]
# Balance : [     0.    83807.86 159660.8  ...  57369.61  75075.31 130142.79]
# NumOfProducts : [1 3 2 4]
# HasCrCard : [1 0]
# IsActiveMember : [1 0]
# EstimatedSalary : [101348.88 112542.58 113931.57 ...  42085.58  92888.52  38190.78]
# Exited : [1 0]
# Geography_France : [1 0]
# Geography_Germany : [0 1]
# Geography_Spain : [0 1]

# %%
# show some sample to check results
df2.sample(10)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7675          640       1   37       5  158024.38              1          1
# 2575          551       1   54       5  102994.04              1          1
# 2901          498       1   73       2  170241.70              2          1
# 7179          613       1   42       7  115076.06              1          1
# 9904          690       0   36      10   91760.11              1          1
# 6122          619       1   44       3  116967.68              1          1
# 4502          698       1   45       5  164450.94              1          1
# 4144          655       1   44       8   87471.63              1          0
# 7423          699       1   36       2  123601.56              2          1
# 7905          701       1   35      10  159693.90              2          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 7675               0         81298.09       0                 0
# 2575               0        176680.16       1                 0
# 2901               1        165407.96       0                 1
# 7179               1         79323.61       0                 1
# 9904               1        135784.94       0                 0
# 6122               0          5075.17       1                 1
# 4502               0        141970.02       1                 0
# 4144               1        188593.98       0                 1
# 7423               0        103557.85       0                 0
# 7905               1         71173.64       0                 0
#
#       Geography_Germany  Geography_Spain
# 7675                  0                1
# 2575                  1                0
# 2901                  0                0
# 7179                  0                0
# 9904                  0                1
# 6122                  0                0
# 4502                  0                1
# 4144                  0                0
# 7423                  1                0
# 7905                  0                1

# %%
df2.dtypes
# Out:
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_France       int64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %%
#drop

# %%
# Scale some columns
cols_to_scale=['CreditScore','Balance','EstimatedSalary']
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df2[cols_to_scale]=scaler.fit_transform(df2[cols_to_scale])

# %%
df2.sample(10)
# Out:
#       CreditScore  Gender  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 8180        0.788       1   42       1  0.448070              1          1
# 1942        0.668       1   45       6  0.590165              1          1
# 4332        0.314       1   31       2  0.535026              1          1
# 2036        0.864       1   34       6  0.587579              1          0
# 6168        0.458       0   26      10  0.647605              1          1
# 5583        0.690       0   31       8  0.000000              2          0
# 849         0.710       1   25       0  0.388781              1          0
# 7281        0.558       1   59       9  0.453004              1          1
# 5501        0.562       0   31       8  0.548779              1          1
# 9201        0.216       0   43       1  0.425950              2          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 8180               1         0.415096       0                 1
# 1942               0         0.917905       0                 1
# 4332               1         0.832140       1                 0
# 2036               1         0.210680       0                 0
# 6168               1         0.092242       0                 1
# 5583               1         0.658227       0                 0
# 849                1         0.299406       0                 1
# 7281               1         0.584242       1                 1
# 5501               0         0.950368       0                 1
# 9201               0         0.502812       0                 0
#
#       Geography_Germany  Geography_Spain
# 8180                  0                0
# 1942                  0                0
# 4332                  1                0
# 2036                  0                1
# 6168                  0                0
# 5583                  0                1
# 849                   0                0
# 7281                  0                0
# 5501                  0                0
# 9201                  1                0
